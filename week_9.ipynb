# %% [markdown]
# # Week 9 handin

# %% [markdown]
# ## 01 Assignment
# https://github.com/Hartmannsolution/docker_notebooks/blob/master/notebooks/09-Exercise.ipynb
#
# Data = 'https://think.cs.vt.edu/corgis/datasets/csv/cars/cars.csv'
#
# Download the data
#
# Programatically download the data from the above link.
#
# Import the data into a Pandas dataframe.
#
# Show the head of the Pandas dataframe.
#
# Feature engineering
#
# Reduce the dataset by:
#
# Make == Honda
#
# Fueltype == Gasoline
#
# Remove outliers. Hint: df[column name'] < df['column name'].quantile(0.90)
#
# Only use 2 features: 'Fuel Information.Highway mpg' and 'Engine Information.Engine Statistics.Horsepower'
#
# Normalize data (reduce values to be between 0 and 1)
#
# Linear regression
#
# Perform linear regression where x = horsepower and y = mpg
#
# What is the coefficient (slope) of your model? What does this number mean?
#
# According to your model, what is y when x=1.
#
# Show the regression line on a scatterplot with the other datapoints.

# %% [markdown]
# ## 02 Status

# %% [markdown]
# ## 03 Solution

# %%
import pandas as pd

data = pd.read_csv('https://think.cs.vt.edu/corgis/datasets/csv/cars/cars.csv')


data.head()
# Out:
#    Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                140                143               202
# 1                140                143               202
# 2                140                143               202
# 3                140                143               202
# 4                140                143               202
#
#   Engine Information.Driveline                Engine Information.Engine Type  \
# 0              All-wheel drive          Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 1            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 2            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 3              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 4              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
#
#    Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                       True                                           6
# ...

# %%
honda = data[data['Identification.Make']== 'Honda']

honda
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 101                 152                240                57
# 102                 152                240                57
# 103                 152                240                57
# 104                 152                240                57
# 105                 152                240                57
# ...                 ...                ...               ...
# 5067                  3                253               201
# 5068                  3                253               201
# 5069                  3                253               201
# 5070                  3                253               201
# 5071                 13                253               201
#
#      Engine Information.Driveline           Engine Information.Engine Type  \
# 101             Front-wheel drive   Honda 3.5L 6 Cylinder 271hp 251 ft-lbs
# 102             Front-wheel drive  Honda 2.4L 4 cylinder 190 hp 162 ft-lbs
# ...

# %%
gasoline = data[data['Fuel Information.Fuel Type']== 'Gasoline']

gasoline
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                   140                143               202
# 1                   140                143               202
# 2                   140                143               202
# 3                   140                143               202
# 4                   140                143               202
# ...                 ...                ...               ...
# 5071                 13                253               201
# 5072                141                249               108
# 5073                160                249               108
# 5074                200                210               110
# 5075                200                 94               110
#
#      Engine Information.Driveline  \
# 0                 All-wheel drive
# 1               Front-wheel drive
# 2               Front-wheel drive
# 3                 All-wheel drive
# 4                 All-wheel drive
# ...

# %%
honda_gasoline = honda[honda['Fuel Information.Fuel Type']== 'Gasoline']

honda_gasoline
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 101                 152                240                57
# 102                 152                240                57
# 103                 152                240                57
# 104                 152                240                57
# 105                 152                240                57
# ...                 ...                ...               ...
# 5067                  3                253               201
# 5068                  3                253               201
# 5069                  3                253               201
# 5070                  3                253               201
# 5071                 13                253               201
#
#      Engine Information.Driveline           Engine Information.Engine Type  \
# 101             Front-wheel drive   Honda 3.5L 6 Cylinder 271hp 251 ft-lbs
# 102             Front-wheel drive  Honda 2.4L 4 cylinder 190 hp 162 ft-lbs
# ...

# %%
outliers_removed_mask = honda_gasoline['Fuel Information.Highway mpg'] < honda_gasoline['Fuel Information.Highway mpg'].quantile(0.90)

outliers_removed_one = honda_gasoline[outliers_removed_mask]

outliers_removed_one
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 101                 152                240                57
# 102                 152                240                57
# 103                 152                240                57
# 104                 152                240                57
# 105                 152                240                57
# ...                 ...                ...               ...
# 5067                  3                253               201
# 5068                  3                253               201
# 5069                  3                253               201
# 5070                  3                253               201
# 5071                 13                253               201
#
#      Engine Information.Driveline           Engine Information.Engine Type  \
# 101             Front-wheel drive   Honda 3.5L 6 Cylinder 271hp 251 ft-lbs
# 102             Front-wheel drive  Honda 2.4L 4 cylinder 190 hp 162 ft-lbs
# ...

# %%
outliers_removed_mask_two = outliers_removed_one['Engine Information.Engine Statistics.Horsepower'] < outliers_removed_one['Engine Information.Engine Statistics.Horsepower'].quantile(0.90)

outliers_removed_two = outliers_removed_one[outliers_removed_mask_two]

outliers_removed_two
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 102                 152                240                57
# 103                 152                240                57
# 104                 152                240                57
# 106                 152                240                57
# 107                 152                240                57
# ...                 ...                ...               ...
# 5067                  3                253               201
# 5068                  3                253               201
# 5069                  3                253               201
# 5070                  3                253               201
# 5071                 13                253               201
#
#      Engine Information.Driveline           Engine Information.Engine Type  \
# 102             Front-wheel drive  Honda 2.4L 4 cylinder 190 hp 162 ft-lbs
# 103             Front-wheel drive  Honda 2.4L 4 cylinder 190 hp 162 ft-lbs
# ...

# %%
from sklearn import preprocessing
reduced = outliers_removed_two[['Fuel Information.Fuel Type', 'Identification.Make', 'Fuel Information.Highway mpg', 'Engine Information.Engine Statistics.Horsepower']]
cut = reduced[['Fuel Information.Highway mpg', 'Engine Information.Engine Statistics.Horsepower']]

cut
# Out:
#       Fuel Information.Highway mpg  \
# 102                             31
# 103                             31
# 104                             31
# 106                             31
# 107                             31
# ...                            ...
# 5067                            25
# 5068                            24
# 5069                            25
# 5070                            24
# 5071                            25
#
#       Engine Information.Engine Statistics.Horsepower
# 102                                               190
# 103                                               190
# 104                                               190
# 106                                               190
# 107                                               190
# ...                                               ...
# 5067                                              250
# 5068                                              250
# ...

# %%
from sklearn import preprocessing

scaler = preprocessing.MinMaxScaler()
names = cut.columns
d = scaler.fit_transform(cut)
scaled_df = pd.DataFrame(d, columns=names)
scaled_df
# Out:
#      Fuel Information.Highway mpg  \
# 0                        0.733333
# 1                        0.733333
# 2                        0.733333
# 3                        0.733333
# 4                        0.733333
# ..                            ...
# 134                      0.333333
# 135                      0.266667
# 136                      0.333333
# 137                      0.266667
# 138                      0.333333
#
#      Engine Information.Engine Statistics.Horsepower
# 0                                           0.548872
# 1                                           0.548872
# 2                                           0.548872
# 3                                           0.548872
# 4                                           0.548872
# ..                                               ...
# 134                                         1.000000
# 135                                         1.000000
# 136                                         1.000000
# ...

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sb

X = scaled_df[['Engine Information.Engine Statistics.Horsepower']]
Y = scaled_df[['Fuel Information.Highway mpg']]
model = LinearRegression(normalize=True)
model.fit(X,Y)
print(model.score(X,Y))
#coefficienten er hvor meget mindre man kører pr gallon når horsepower stiger med 1
print(model.coef_)

plt.scatter(X,Y)
plt.plot(X,model.predict(X),color='green')
plt.title("Regression Model")
plt.xlabel("Horsepower")
plt.ylabel("Highway mpg")
# Out:
# 0.5379512935197266
# [[-0.68515772]]
# Text(0, 0.5, 'Highway mpg')

# %%
print(model.predict([[1]]))
# Out:
# [[0.29254137]]
